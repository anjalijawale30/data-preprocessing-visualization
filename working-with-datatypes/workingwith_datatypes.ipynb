# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb029eca-6fa8-4c95-9bf3-1e6ef2f6a8ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb029eca-6fa8-4c95-9bf3-1e6ef2f6a8ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv('database.csv')

# %%
df2 = df1[:1000] #slicing
df2.to_csv('significant_earthquake.csv')

# %%
df2 = pd.read_csv('significant_earthquake.csv')

# %%
df2=pd.read_csv('significant_earthquake.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0        Date      Time  Latitude  Longitude        Type  Depth  \
# 0           0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6
# 1           1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0
# 2           2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3           3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4           4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0          NaN                     NaN        6.0  ...
# 1          NaN                     NaN        5.8  ...
# 2          NaN                     NaN        6.2  ...
# 3          NaN                     NaN        5.8  ...
# 4          NaN                     NaN        5.8  ...
#
#   Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                        NaN            NaN                  NaN
# ...

# %%
df2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df2.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
df2['Latitude'].dtypes
# Out:
# dtype('float64')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1000 non-null   object
#  1   Time                        1000 non-null   object
#  2   Latitude                    1000 non-null   float64
#  3   Longitude                   1000 non-null   float64
#  4   Type                        1000 non-null   object
#  5   Depth                       1000 non-null   float64
#  6   Depth Error                 4 non-null      float64
#  7   Depth Seismic Stations      4 non-null      float64
#  8   Magnitude                   1000 non-null   float64
#  9   Magnitude Type              1000 non-null   object
#  10  Magnitude Error             3 non-null      float64
#  11  Magnitude Seismic Stations  4 non-null      float64
#  12  Azimuthal Gap               4 non-null      float64
# ...

# %%
df2=df2.copy()
df2['Latitude']=df2['Latitude'].astype('int64')
df2.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                        int64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
df2.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                        int64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
df2["Date"]=pd.to_datetime(df2["Date"],format='%m/%d/%Y')

# %%
df2.dtypes
# Out:
# Date                          datetime64[ns]
# Time                                  object
# Latitude                               int64
# Longitude                            float64
# Type                                  object
# Depth                                float64
# Depth Error                          float64
# Depth Seismic Stations               float64
# Magnitude                            float64
# Magnitude Type                        object
# Magnitude Error                      float64
# Magnitude Seismic Stations           float64
# Azimuthal Gap                        float64
# Horizontal Distance                  float64
# Horizontal Error                     float64
# Root Mean Square                     float64
# ID                                    object
# Source                                object
# Location Source                       object
# Magnitude Source                      object
# Status                                object
# ...

# %%
df2.head(5)
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02  13:44:18        19    145.616  Earthquake  131.6          NaN
# 1 1965-01-04  11:29:49         1    127.352  Earthquake   80.0          NaN
# 2 1965-01-05  18:05:58       -20   -173.972  Earthquake   20.0          NaN
# 3 1965-01-08  18:49:43       -59    -23.557  Earthquake   15.0          NaN
# 4 1965-01-09  13:32:50        11    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df2["Date"][1]-df2["Date"][0] #find date difference
# Out:
# Timedelta('2 days 00:00:00')

# %%
df2['Date'][1]
# Out:
# Timestamp('1965-01-04 00:00:00')

# %%
df2["Date"][1].day
# Out:
# 4

# %%
df2["Date"][1].month
# Out:
# 1

# %%
df2["Date"][1].year
# Out:
# 1965

# %%
decimals=df2.select_dtypes('float')
decimals.head()
# Out:
#    Longitude  Depth  Depth Error  Depth Seismic Stations  Magnitude  \
# 0    145.616  131.6          NaN                     NaN        6.0
# 1    127.352   80.0          NaN                     NaN        5.8
# 2   -173.972   20.0          NaN                     NaN        6.2
# 3    -23.557   15.0          NaN                     NaN        5.8
# 4    126.427   15.0          NaN                     NaN        5.8
#
#    Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 0              NaN                         NaN            NaN
# 1              NaN                         NaN            NaN
# 2              NaN                         NaN            NaN
# 3              NaN                         NaN            NaN
# 4              NaN                         NaN            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square
# 0                  NaN               NaN               NaN
# 1                  NaN               NaN               NaN
# ...

# %%
decimals.dtypes
# Out:
# Longitude                     float64
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# dtype: object

# %%
number_data=df2.select_dtypes(exclude='object')

# %%
number_data.head()
# Out:
#         Date  Latitude  Longitude  Depth  Depth Error  Depth Seismic Stations  \
# 0 1965-01-02        19    145.616  131.6          NaN                     NaN
# 1 1965-01-04         1    127.352   80.0          NaN                     NaN
# 2 1965-01-05       -20   -173.972   20.0          NaN                     NaN
# 3 1965-01-08       -59    -23.557   15.0          NaN                     NaN
# 4 1965-01-09        11    126.427   15.0          NaN                     NaN
#
#    Magnitude  Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 0        6.0              NaN                         NaN            NaN
# 1        5.8              NaN                         NaN            NaN
# 2        6.2              NaN                         NaN            NaN
# 3        5.8              NaN                         NaN            NaN
# 4        5.8              NaN                         NaN            NaN
#
# ...

# %%
number_data.dtypes
# Out:
# Date                          datetime64[ns]
# Latitude                               int64
# Longitude                            float64
# Depth                                float64
# Depth Error                          float64
# Depth Seismic Stations               float64
# Magnitude                            float64
# Magnitude Error                      float64
# Magnitude Seismic Stations           float64
# Azimuthal Gap                        float64
# Horizontal Distance                  float64
# Horizontal Error                     float64
# Root Mean Square                     float64
# dtype: object

# %%
dtypes_dict={"Depth":"object",}

# %%
df3=pd.read_csv('significant_earthquake.csv', dtype=dtypes_dict)

# %%
df3.dtypes
# Out:
# Unnamed: 0                      int64
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Type                           object
# Depth                          object
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1000 non-null   int64
#  1   Date                        1000 non-null   object
#  2   Time                        1000 non-null   object
#  3   Latitude                    1000 non-null   float64
#  4   Longitude                   1000 non-null   float64
#  5   Type                        1000 non-null   object
#  6   Depth                       1000 non-null   object
#  7   Depth Error                 4 non-null      float64
#  8   Depth Seismic Stations      4 non-null      float64
#  9   Magnitude                   1000 non-null   float64
#  10  Magnitude Type              1000 non-null   object
#  11  Magnitude Error             3 non-null      float64
#  12  Magnitude Seismic Stations  4 non-null      float64
# ...

# %%
dtypes1={"Type":"category","Status":"category","Source":"category","Location Source":"category","Magnitude Source":"category","Magnitude Type":"category"}
df4=pd.read_csv('significant_earthquake.csv', dtype=dtypes1, parse_dates=['Date','Time'])
# Out:
# /tmp/ipykernel_795/4037549035.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df4=pd.read_csv('significant_earthquake.csv', dtype=dtypes1, parse_dates=['Date','Time'])

# %%
# !pip insatll pandas
# Out:
# ERROR: unknown command "insatll" - maybe you meant "install"

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/diabetes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_832/933340182.py in <cell line: 0>()
# ----> 1 df1 = pd.read_csv('/content/diabetes.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
df1 = pd.read_csv('/content/diabetes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_832/933340182.py in <cell line: 0>()
# ----> 1 df1 = pd.read_csv('/content/diabetes.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ff58f4a-b0b2-442d-b05a-ac2c0807e6f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ff58f4a-b0b2-442d-b05a-ac2c0807e6f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv('diabetes.csv')

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df1.describe() #statastically summary
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data_cols = ['Glucose','BloodPressure','SkinThickness','Insulin',	'BMI']

# %%
(df1[data_cols] == 0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
df1.isnull.sum()  #count for null values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_832/730236629.py in <cell line: 0>()
# ----> 1 df1.isnull.sum()  #count for null values
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df1.isnull().sum()  #count for null values
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
from numpy import nan

# %%
df1[data_cols] = df1[data_cols].replace(0,nan)  #replace all the 0 values with nan

# %%
df1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df1.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6    148.0           72.0           35.0      NaN  33.6
# 1             1     85.0           66.0           29.0      NaN  26.6
# 2             8    183.0           64.0            NaN      NaN  23.3
# 3             1     89.0           66.0           23.0     94.0  28.1
# 4             0    137.0           40.0           35.0    168.0  43.1
# 5             5    116.0           74.0            NaN      NaN  25.6
# 6             3     78.0           50.0           32.0     88.0  31.0
# 7            10    115.0            NaN            NaN      NaN  35.3
# 8             2    197.0           70.0           45.0    543.0  30.5
# 9             8    125.0           96.0            NaN      NaN   NaN
# 10            4    110.0           92.0            NaN      NaN  37.6
# 11           10    168.0           74.0            NaN      NaN  38.0
# ...

# %%
df1 = df1.dropna(subset=['Glucose','BloodPressure','BMI'])  #deleting missing values and use dropna when missing values are small so it won't affect dataset

# %%
df1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness               192
# Insulin                     332
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
mean_val = df['Insulin'].mean()  #using mean value for replacing missing value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_832/2887038486.py in <cell line: 0>()
# ----> 1 mean_val = df['Insulin'].mean()  #using mean value for replacing missing value
#
# NameError: name 'df' is not defined

# %%
mean_val = df1['Insulin'].mean()  #using mean value for replacing missing value

# %%
print(mean_val)
# Out:
# 156.05612244897958

# %%
df1['Insulin'] = df1['Insulin'].fillna(mean_val) #use mean when data is numerical and distribution is normal

# %%
df1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness               192
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df1['SkinThickness'].interpolate() #interppolate -time series data and sequential data
# Out:
# 0      35.0
# 1      29.0
# 2      26.0
# 3      23.0
# 4      35.0
#        ...
# 763    48.0
# 764    27.0
# 765    23.0
# 766    27.0
# 767    31.0
# Name: SkinThickness, Length: 724, dtype: float64

# %%
df1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
